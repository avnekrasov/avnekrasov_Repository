# %%
from IPython.display import YouTubeVideo
YouTubeVideo('lyDLAutA88s', width=800, height=300)

# %%
# 1. Посмотрите видео Дэвида Бизли про всроенные инструменты Python
# 2. Попробуйте используя встроенные инструменты Python проанализировать таблицу из файла "Vacancy.csv"
# 3. Попробуйте ответить на вопросы:
# Сколько вакансий, которые вам нравятся?
# Насколько свежие эти вакансии?
# Сколько вакансий с позициями на которых вы работаете?
# Сколько вакансий для аналатика данных?
# Сколько вакансий для аналитика данных с использованием Python?

# В задании важно не использовать pandas и numpy, а встроенные инструменты python
# Counter, CSV, defaultdict, sorted

# %%
import sys
import csv
maxInt = sys.maxsize

while True:
    # decrease the maxInt value by factor 10 
    # as long as the OverflowError occurs.

    try:
        csv.field_size_limit(maxInt)
        break
    except OverflowError:
        maxInt = int(maxInt/10)

# %%
csv.field_size_limit(1000000000)
# Out:
# 100000000

# %%
#import csv
#with open("Vacancy.csv", encoding='utf-8') as file:
#    data_reader = csv.reader(file, delimiter = ",", quoting=csv.QUOTE_NONE)
#    for line in data_reader:
#        print (line)

# %%
#with open('Vacancy.csv', encoding='utf-8') as f:
#    reader = csv.DictReader(f)
#    for row in reader:
#        print(row['vactitle'], row['created_at'] )

# %%
vacs = list(csv.DictReader(open('Vacancy.csv', encoding='utf-8')))

# %%
dates = []
for v in vacs:
    dates.append(v.get('created_at'))

# %%
from collections import Counter
c = Counter(dates)

# %%
c.most_common()
# Out:
# [('2021-03-14 09:39:21.854462', 4002)]

# %%
c.keys()
# Out:
# dict_keys(['2021-03-14 09:39:21.854462'])

# %%
c.get('2021-03-14 09:39:21.854462')
# Out:
# 4002

# %%
list(set(dates))
# Out:
# ['2021-03-14 09:39:21.854462']

# %%
vacancies = []
for v in vacs:
    vacancies.append(v.get('vactitle'))

# %%
from collections import Counter
vac = Counter(vacancies)

# %%
vac.most_common(10)
# Out:
# [('Мобильный менеджер по продажам', 229),
#  ('Старший менеджер по обслуживанию', 172),
#  ('Специалист по прямым продажам', 164),
#  ('Менеджер по продажам', 86),
#  ('Системный аналитик', 62),
#  ('Менеджер по работе с ключевыми клиентами малого бизнеса', 53),
#  ('Java разработчик', 40),
#  ('Водитель-инкассатор', 38),
#  ('Старший специалист по взысканию задолженности', 38),
#  ('Главный клиентский менеджер малого бизнеса', 34)]

# %%
vac.keys()
# Out:
# dict_keys(['Senior java-разработчик (в команду Онбординга)', 'Дизайнер мобильных приложений', 'Старший специалист отдела мониторинга залогового обеспечения', "Аналитик/разработчик  (Программа 'Миграция Legacy АС на Фабрику Данных')", 'Java разработчик (Команда Functions)', 'Главный инженер (NGFW)', 'Ведущий инженер по кибербезопасности (защита контейнеров)', 'Тестировщик-автоматизатор (QA)', 'Ведущий специалист (отдел технических средств охраны)', 'Инженер поддержки тестирования', 'Data - аналитик', 'Ведущий специалист (Управление комплаенс)', 'Клиентский менеджер по работе с корпоративными клиентами', 'Главный инженер (Pentest)', 'DevOps (центр снабжения)', 'QA', 'Data engineer (BigData и ML)', 'Лидер АС', 'Системный аналитик. Сервис Автокредитование', 'Руководитель направления ABAP', 'ABAP разработчик под АСУС EWM', 'Аналитик (информационная безопасность)', 'Разработчик ABAP', 'Инженер по разработке', 'Frontend разработчик (React)КБ', 'Product owner AI решений', 'Руководитель проектов', 'Backend-разработчик (web)', 'Front-end разработчик (React, JS)', 'Системный аналитик', 'Java Lead / Java Developer', 'Старший менеджер по обслуживанию (пгт Новоаганск)', 'Стажер', 'Менеджер по продажам (п. Солнечный)', 'Java-разработчик (HR-платформа)', 'Кредитный инспектор отдела мониторинга кредитных операций торговли', 'Стажер школы SQL, PL\\SQL', 'Инженер по нагрузочному тестированию', 'Старший аудитор по проверкам кредитных операций физических лиц', 'JavaScript разработчик(Backend)', 'Инженер Удостоверяющего центра', 'Главный специалист по телемаркетингу', 'Менеджер по нефинансовым сервисам (продажи продуктов экосистемы Сбера корпоративным клиентам)', 'Старший специалист по взысканию', 'Главный дизайнер мобильных приложений', 'Старший дизайнер мобильных приложений', 'Java разработчик', 'Java. groovy разработчик', 'Главный специалист по взысканию', 'Главный инженер по разработке', 'Мобильный менеджер по продажам', 'Ведущий специалист по взысканию', 'Менеджер по продажам продуктов канала', 'Старший менеджер по обслуживанию (г. Туринск, 7003/0778)', 'Стажер Sberseasons iOS весна \ue013', 'Старший инженер', 'Руководитель направления/Аналитик AI решений', 'Бизнес/системный аналитик', 'Старший менеджер по обслуживанию', 'Lead Frontend Developer', 'Менеджер по продажам (ЗАТО Озерный)', 'Старший кассир', 'Специалист по прямым продажам', 'Главный клиентский менеджер малого бизнеса', 'Front-end разработчик (RIA/SPA приложения)', 'Ведущий инженер по автоматизированному тестированию', 'Менеджер по продажам (с. Кизильское)', 'Разработчик SAS', 'Менеджер по продаже зарплатных проектов', 'Android-разработчик (Сервисы ʺПлати QRʺ)', 'Java Developer', 'Frontend разработчик (React)', 'Frontend developer JavaScript (React/Redux)', 'Java developer', 'Тестировщик ПО (QA Automation Engineer)', 'Ведущий инженер (сопровождение системы визуализации отчетности)', 'Старший менеджер по обслуживанию (с. Рудянское)', 'QA Automation Engineer (Python)', 'Инженер по диспетчеризации ЦОД', 'Водитель-инкассатор', 'Ведущий менеджер по обслуживанию', 'Python разработчик (команда "ИСУ")', 'Специалист по разметке данных', 'Аналитик на разметку данных', 'Консультант по работе с ПФР', 'Технологический руководитель команды', 'Эксперт', 'Менеджер в Департамент Стратегии (IT/E-Government)', 'Старший специалист судебного и исполнительного производства', 'Водитель', 'IT Аналитик', 'Выездной клиентский менеджер', 'Начальник сектора', 'Методолог', 'Главный специалист (Риски корпоративно-инвестиционного бизнеса)', 'Инженер по сопровождению', 'Senior Java Developer', 'Ст.менеджер по продаже жилищ.кредитов', 'Аналитик SQL (кампании продаж)', 'Senior Data scientist (Кампании продаж)', 'PR менеджер SmartMarket и ассистентов Салют', 'Клиентский менеджер удаленных продаж', 'DevOps Engineer (Маркетинг)', 'Data engineer (ISAP)', 'Старший инженер по разработке', 'Специалист сектора развития инфраструктуры', 'Менеджер по обслуживанию', 'Системный аналитик(проект интернализация платежей)', 'Бизнес ...

# %%
vacancy_df_test['key_skills']
# Out:
# 40

# %%
len(vacancies)
# Out:
# 4002

# %%
c= 0
for i in vacancies:
    if 'Python' in i:
        c += 1
print (c)
# Out:
# 29

# %%
c= 0
for i in vacancies:
    if 'Аналитик данных' in i:
        c += 1
print (c)
# Out:
# 15
